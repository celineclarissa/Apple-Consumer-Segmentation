# %% [markdown]
# # Apple Brand Appeal: A Study of International Students at CUHK-Shenzhen
#
# Name: Celine Clarissa Chandra
#
# This study was conducted as a part of the ENG2001: English for Academic Purposes course at The Chinese University of Hong Kong (Shenzhen).

# %% [markdown]
# ## Abstract
# Apple Inc.’s marketing strategies are reported to impact university students’ consumption behavior. However, previous studies focused on overall students, not specifically on international students in China. This demographic has a more equal exposure to both cultures. Quantitative and qualitative approaches were used to study 52 international students at a Sino-foreign university, utilizing surveys, proceeded with data clustering and statistical analyses. Results show that within the demographic, there were two groups with different perceptions towards Apple products: skeptic and enthusiast, directly influencing purchase intentions. Findings align with previous research about university students’ and society’s view on Apple products.

# %% [markdown]
# ## Introduction
# Apple Inc. is a world-renowned company specializing in technological products such as iPhones, iPads, MacBooks, to AirPods and other electrical accessories. Their choice of design style in goods and their unique brand presence act as an appeal to customers. This aligns with Apple Inc.’s core branding strategy: empathy, focus, impute, which are reflected in how they utilize humanity, building emotional bonds with users and affecting consumer behavior (Cai & Chen, 2024).
#
# China, with a population of 1.4 billion (World Bank, 2024), acts as a prominent market for Apple Inc.’s brand expansion. This includes Shenzhen, an economic and technological hub, and a rising immigrant city (Information Office of Shenzhen Municipal Government). One of the institutions attracting international students is The Chinese University of Hong Kong, Shenzhen (CUHK-Shenzhen), a university promoting cultural exchange among their students. International students at CUHK-Shenzhen are exposed to both western and eastern media, culture, and technologies. Past studies have examined about Apple Inc.’s marketing strategy in China and other countries, but little is known about how it affects the perception and behavior of international students who have a more equal access to both environments. Therefore, this research aims to bridge that gap, providing information for both companies to further assess current initiatives towards this market segment and the people.

# %% [markdown]
# ## Literature Review
# Apple Inc.’s growth is a result of their innovations, design, cutting-edge operating system, and cloud computing technology (Chen et al., 2021). As a global leading company, not only their technologies are exceptional, but also their unique branding among other enterprises in the industry. This initiative includes framing their products as a social symbol and enhancing consumer experience in retail stores (Lan, 2021). This strategy targets key factors of consumer behavior for their brand, which Nagamia (2015) identified as psychological aspects and sociocultural aspects, such as lifestyle and social status.
#
# Douglas (2021) found that Apple products are romanticized by undergraduate students in Nigeria, showing how lifestyle and symbolic value contributes to purchasing decisions. Additionally, Li (2023) found that Apple Inc.’s brand positioning and marketing strategy is effective in attaining a positive reputation within the Chinese market. However, there was a significant gap in understanding how Apple Inc.’s marketing schemes are interpreted by those the younger generation who are exposed to both Chinese and western media, culture, and technologies, which according to Wells & Prensky (1996) can affect consumer behavior. This demographic included international students studying at CUHK-Shenzhen. Hence, this research focused on answering the research questions below.
# 1.	How do international students at CUHK-Shenzhen perceive Apple Inc.’s brand identity?
# 2.	What factors drive or hinder international students at CUHK-Shenzhen from purchasing Apple products?

# %% [markdown]
# ## Methods
# A Google Form, including Likert-scales, checkboxes, multiple-choice, and open-ended questions was used to collect quantitative and qualitative data from 52 active CUHK-Shenzhen international students to gain a comprehensive understanding of the research problem. The questionnaire included three sections: demographic, brand perception, purchase drivers and barriers.
#
# The data was used for quantitative and qualitative analyses. K-means clustering was used to group respondents based on their perception and behavioral drivers (psychographic and behavioral-based consumer segmentation), an important for marketing strategies (Schlegelmilch, 2022). Then, descriptive and inferential statistics (mean and two-sample t-test) were used to identify trends, while the qualitative analysis utilized a thematic method to enhance findings from the quantitative analyses.

# %% [markdown]
# ### i. Import Libraries

# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Import feature engineering
from scipy import stats
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')
from sklearn.decomposition import PCA
import matplotlib.cm as cm
from sklearn.metrics import silhouette_score, silhouette_samples

# Import model
from sklearn.cluster import KMeans

# Import model saving
import pickle
import json

# %% [markdown]
# ### ii. Data Loading and Data Cleaning

# %%
df_ori = pd.read_excel('Apple in a Cross-Cultural Context_ Brand Perception, Purchase Drivers, and the Role of Cultural Exposure Among CUHK (SZ) International Students (Responses).xlsx')
pd.set_option('display.max_columns', None)
df_ori.head()
# Out:
#                 Timestamp Home Country  Age  Gender  \
# 0 2025-11-17 12:23:41.413    Indonesia   19  Female
# 1 2025-11-17 12:31:44.160    indonesia   19  Female
# 2 2025-11-17 12:37:02.855    Indonesia   19  Female
# 3 2025-11-17 12:38:17.328   Indonesian   19  Female
# 4 2025-11-17 12:45:59.377    Indonesia   19  Female
#
#   What is your primary language for media consumption?  \
# 0                                            English
# 1                                           english
# 2                                            English
# 3                                            English
# 4                                            English
#
#    Apple is a premium brand  Apple products are innovative  \
# 0                         5                              6
# 1                         6                              6
# 2                         5                              3
# 3                         6                              3
# ...

# %%
df = df_ori.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 31 columns):
#  #   Column                                                                                                                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                     --------------  -----
#  0   Timestamp                                                                                                                                                                                                                  52 non-null     datetime64[ns]
# ...

# %%
df.describe()
# Out:
#                            Timestamp        Age  Apple is a premium brand  \
# count                             52  52.000000                 52.000000
# mean   2025-11-20 22:15:53.677807616  19.057692                  4.788462
# min       2025-11-17 12:23:41.413000  18.000000                  2.000000
# 25%    2025-11-17 13:27:15.325250048  19.000000                  4.000000
# 50%    2025-11-19 03:58:13.304999936  19.000000                  5.000000
# 75%    2025-11-24 18:44:00.370749952  19.000000                  5.250000
# max       2025-11-27 19:38:16.074000  21.000000                  6.000000
# std                              NaN   0.574404                  0.976921
#
#        Apple products are innovative  \
# count                      52.000000
# mean                        3.826923
# min                         1.000000
# 25%                         3.000000
# 50%                         4.000000
# 75%                         5.000000
# ...

# %%
df.nunique()
# Out:
# Timestamp                                                                                                                                                                                                                    52
# Home Country                                                                                                                                                                                                                  9
# Age                                                                                                                                                                                                                           4
# Gender                                                                                                                                                                                                                        2
# ...

# %%
# Check for missing values
df.isnull().sum().sum()
# Out:
# 0

# %%
# Check for duplicated data
df.duplicated().sum()
# Out:
# 0

# %%
# Check unique values for each column
for i in ['Home Country', 'Age', 'What is your primary language for media consumption?']:
    print(f'Unique values in column {i} : {df[i].unique()}')
# Out:
# Unique values in column Home Country : ['Indonesia' 'indonesia' 'Indonesian' 'Indonesia ' 'Indonesian '
#  'Thailand' 'Thailand ' 'Kazakhstan ' 'Kazakhstan']
# Unique values in column Age : [19 18 20 21]
# Unique values in column What is your primary language for media consumption? : ['English' 'english ' 'english' 'Indonesian & English' 'Indonesian'
#  'Indonesia' 'Thai' 'English ' 'Russian' 'English, Russian']

# %%
df = df.rename(columns={'Home Country':'Home_Country',
                        'What is your primary language for media consumption?':'Primary_Language',
                        'What three words/phrases would you use to describe the brand Apple?':'Phrases_Describe_Apple',
                        'Which of the following Apple products do you currently own?': 'Products_Owned',
                        'If you have chosen NOT to purchase an Apple product, what was the main reason?':'Reason_Not_Buy',
                        'To what extent were you familiar with and exposed to Apple products/brand in your home country before coming to China?':'Prior_Familiarity',
                        'Since arriving in China, has your perception of the Apple brand changed?':'Change_in_Perception',
                        'Reflecting on your time in Shenzhen, how has living in this specific cultural and tech environment shaped your view of Apple as a brand? For example, has it made you more or less likely to use their products, and why?':'Changes_After_China'})

df['Home_Country'] = df['Home_Country'].str.strip().str.capitalize()
df['Primary_Language'] = df['Primary_Language'].str.strip().str.capitalize()
df['Home_Country'] = df['Home_Country'].replace({'Indonesian':'Indonesia'})
df['Primary_Language'] = df['Primary_Language'].replace({'Indonesian':'Indonesia'})

Owned = df['Products_Owned'].copy()
Owned = Owned.str.get_dummies(', ')
Owned = Owned.rename(columns={'AirPods or AirPods Pro':'Airpods',
                              'Apple mouse':'Apple Mouse',
                              'None of the above':'None'})
Owned['n_Owned'] = Owned[['Airpods', 'Apple Watch', 'Apple Mouse', 'MacBook', 'iPad', 'iPhone']].sum(axis=1)
df = pd.concat([df, Owned], axis=1)

Phrases, Changes = df['Phrases_Describe_Apple'].copy().to_frame(name='Phrases'), df['Changes_After_China'].copy().to_frame(name='Changes')

df = df[['Home_Country', 'Age', 'Gender', 'Primary_Language',
       'Apple is a premium brand', 'Apple products are innovative',
       'Apple products are well-designed and aesthetically pleasing',
       "Apple's brand reputation makes them a trustworthy brand",
       'Owning Apple products affects how others perceive me',
       'Using Apple products make me feel like a part of a global community',
       'The Apple brand aligns with my personal values and identity',
       'Airpods', 'Apple Watch', 'Apple Mouse', 'MacBook', 'iPad', 'iPhone', 'n_Owned', 'None',
       'Recommendations from friends/family back home',
       'Recommendations from friends at CUHK(SZ)', 'Price and value for money',
       'Brand reputation and image', 'Design, build quality, and aesthetics',
       'Technical specifications (RAM, memory, battery, camera)',
       'Operating system (e.g. iOS vs. Android)',
       'Integration with my other devices',
       'Reason_Not_Buy', 'Prior_Familiarity', 'Change_in_Perception',
       'My awareness of Chinese tech brands (e.g. Xiaomi, Huawei) has significantly increased since living here',
       'My tech preferences have been influenced by what is popular or practical among my peers in Shenzhen',
       'Using an Apple product in China feels different from using it in my home country',
       'The tech ecosystem in China (e.g. app availability, payment systems) affects my choice in tech devices',
       'Being exposed to both western and Chinese media has made me more critical of global brands like Apple']]

df.head(3)
# Out:
#   Home_Country  Age  Gender Primary_Language  Apple is a premium brand  \
# 0    Indonesia   19  Female          English                         5
# 1    Indonesia   19  Female          English                         6
# 2    Indonesia   19  Female          English                         5
#
#    Apple products are innovative  \
# 0                              6
# 1                              6
# 2                              3
#
#    Apple products are well-designed and aesthetically pleasing  \
# 0                                                  6
# 1                                                  6
# 2                                                  3
#
#    Apple's brand reputation makes them a trustworthy brand  \
# 0                                                  4
# 1                                                  6
# 2                                                  2
#
#    Owning Apple products affects how others perceive me  \
# ...

# %% [markdown]
# ### iii. Exploratory Data Analysis

# %%
color = ['#3AA6B9', '#ADD899', '#F075AA', '#FFDE95', '#BC5A94', '#FA7070']

# %% [markdown]
# #### 1. Home Country Distribution

# %%
country_counts = df['Home_Country'].value_counts(dropna=False)
country_counts.name = None 

country_counts.plot.pie(colors=color, autopct='%1.1f%%', shadow=True)
plt.title('Overall Home Country Distribution')
plt.axis('equal')
plt.ylabel('')
plt.show()

# %%
country_counts
# Out:
# Home_Country
# Indonesia     47
# Thailand       3
# Kazakhstan     2
# dtype: int64

# %% [markdown]
# #### 2. Age Distribution

# %%
age_counts = df['Age'].value_counts(dropna=False)
age_counts.name = None 

age_counts.plot.pie(colors=color, autopct='%1.1f%%', shadow=True)
plt.title('Overall Age Distribution')
plt.axis('equal')
plt.ylabel('') 
plt.show()

# %%
age_counts
# Out:
# Age
# 19    38
# 20     7
# 18     6
# 21     1
# dtype: int64

# %% [markdown]
# #### 3. Gender Distribution

# %%
gender_counts = df['Gender'].value_counts(dropna=False)
gender_counts.name = None  # Remove the series name

gender_counts.plot.pie(colors=color, autopct='%1.1f%%', shadow=True)
plt.title('Overall Gender Distribution')
plt.axis('equal')
plt.ylabel('')  # Remove y-axis label if it appears
plt.show()

# %%
gender_counts
# Out:
# Gender
# Female    41
# Male      11
# dtype: int64

# %% [markdown]
# #### 4. Media Consumption Language Distribution

# %%
df['Primary_Language'] = df['Primary_Language'].replace({'Indonesian & english':'Indonesian & English', 'Indonesia':'Indonesian', 'English, russian':'English & Russian'})

language_counts = df['Primary_Language'].value_counts(dropna=False)
language_counts.name = None  # Remove the series name

language_counts.plot.pie(colors=color, autopct='%1.1f%%', shadow=True)
plt.title('Distribution of Language Used for Media Consumption')
plt.axis('equal')
plt.ylabel('')  # Remove y-axis label if it appears
plt.show()

# %% [markdown]
# #### 5. Brand Perception - Likert

# %%
perception_likert = df.loc[:, 'Apple is a premium brand':'The Apple brand aligns with my personal values and identity']
perception_likert.describe()[1:]
# Out:
#       Apple is a premium brand  Apple products are innovative  \
# mean                  4.788462                       3.826923
# std                   0.976921                       1.339024
# min                   2.000000                       1.000000
# 25%                   4.000000                       3.000000
# 50%                   5.000000                       4.000000
# 75%                   5.250000                       5.000000
# max                   6.000000                       6.000000
#
#       Apple products are well-designed and aesthetically pleasing  \
# mean                                           4.788462
# std                                            1.177177
# min                                            1.000000
# 25%                                            4.000000
# 50%                                            5.000000
# 75%                                            6.000000
# max                                            6.000000
#
# ...

# %% [markdown]
# #### 6. Brand Perception - Descriptors

# %%
Phrases['Phrases'] = Phrases['Phrases'].str.split(r'[,/&.]').apply(lambda x: [item.strip().capitalize() for item in x if item.strip()])

Phrase_List = []
for i in range(len(Phrases)):
    for j in range(len(Phrases['Phrases'][i])):
        Phrase_List.append(Phrases['Phrases'][i][j])

List = ''
for i in Phrase_List:
    List += ', '+i

List = List[2:]

# %%
Phrase_Frequency = pd.Series(Phrase_List).value_counts()
Phrase_Frequency.head(10)
# Out:
# Expensive     16
# Simple         8
# Aesthetic      8
# Innovative     7
# Premium        5
# Sleek          3
# Exclusive      3
# Ecosystem      3
# Minimalist     3
# Luxury         2
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20,20))
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800, colormap='ocean', background_color='white').generate(List)
plt.title('Words & Phrases Used to Describe Apple')
plt.imshow(wc , interpolation = 'bilinear')

# %% [markdown]
# #### 7. Consumer Behavior - Likert

# %%
behavior_likert = df.loc[:, 'Recommendations from friends/family back home':'Integration with my other devices']
behavior_likert.describe()[1:]
# Out:
#       Recommendations from friends/family back home  \
# mean                                       2.980769
# std                                        0.727348
# min                                        1.000000
# 25%                                        3.000000
# 50%                                        3.000000
# 75%                                        3.000000
# max                                        4.000000
#
#       Recommendations from friends at CUHK(SZ)  Price and value for money  \
# mean                                  2.230769                   3.615385
# std                                   0.807207                   0.565472
# min                                   1.000000                   2.000000
# 25%                                   2.000000                   3.000000
# 50%                                   2.000000                   4.000000
# 75%                                   3.000000                   4.000000
# ...

# %% [markdown]
# #### 8. Consumer Behavior - Challenges of Purchase

# %%
n_reason = df.loc[df['n_Owned']!=0, ['n_Owned', 'Reason_Not_Buy', 'Gender', 'Home_Country']].replace({'I am not convinced of their quality':'Not convinced of their quality',
                                                                                                            'I prefer the features of other brands (e.g. Xiaomi, Huawei)':'Prefer other brands',
                                                                                                            'Apple products are too expensive':'Too expensive'})

# %%
Reason_Not_Own = df.loc[df['n_Owned']==0, ['n_Owned', 'Reason_Not_Buy', 'Gender', 'Home_Country']].replace({'I am not convinced of their quality':'Not convinced of their quality',
                                                                                                            'I prefer the features of other brands (e.g. Xiaomi, Huawei)':'Prefer other brands',
                                                                                                            'Apple products are too expensive':'Too expensive'})

Reason_Not_Own_Counts = Reason_Not_Own['Reason_Not_Buy'].value_counts(dropna=False)
Reason_Not_Own_Counts.plot(kind='barh', color=color[0])

cross_tab = pd.crosstab(Reason_Not_Own['Reason_Not_Buy'], Reason_Not_Own['Gender'])

plt.figure(figsize=(12, 6))
cross_tab.plot(kind='bar', stacked=True, colormap='Set3')
plt.title('Reasons for Not Owning Apple Products by Gender')
plt.xlabel('Reason for Not Buying')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### iv. Clustering (Customer Segmentation)

# %% [markdown]
# ## Results
# This section addresses RQ1 (brand perception) and RQ2 (behavioral factors), analyzing the overall sample and the groups from the clustering algorithm.

# %% [markdown]
# ### Table 1. Means of brand perception scores by overall sample
#
# | Statement | Mean |
# | :---: | :---: |
# | Apple is a premium brand | 4.79 |
# | Apple products are innovative | 3.83 |
# | Apple products are well-desogned and aesthetically pleasing | 4.79 |
# | Apple's brand reputation makes them a trustworthy brand | 4.71 |
# | Owning Apple products affects how others perceive me | 3.21 |
#
# *All scores are derived from 6-scale Likert questions
#
# The overall sample gave higher scores for Apple as a premium, well-designed, and trustworthy brand, all obtaining scores above 4.70. Meanwhile, innovative and socially impactful scored below 4.

# %% [markdown]
# ### Table 2. Top ten phrases used to describe Apple by the overall sample
#
# | Phrase | Frequency |
# | :---: | :---: |
# | Expensive | 16 |
# | Simple | 8 |
# | Aesthetic | 8 |
# | Innovative | 7 |
# | Premium | 5 |
# | Sleek | 3 |
# | Exclusive | 3 |
# | Ecosystem | 3 |
# | Minimalist | 3 |
# | Luxury | 2 |
#
# The most noticeably frequent word mentioned as a descriptor for Apple was “expensive”, with a frequency twice as many as the next most common words, “simple” and “aesthetic”.

# %% [markdown]
# ### Table 3. Means of brand perception scores per group
#
# | Statement | Mean (Group 1) | Mean (Group 2) |
# | :---: | :---: | :---: |
# | Apple is a premium brand | 4.43 | 5.07 |
# | Apple products are innovative | 3.04 | 4.45 |
# | Apple products are well-desogned and aesthetically pleasing | 4.13 | 5.31 |
# | Apple's brand reputation makes them a trustworthy brand | 4.00 | 5.28 |
# | Owning Apple products affects how others perceive me | 2.70 | 4.10 |
#
# *All scores are derived from 6-scale Likert questions
#
# After clustering, the two groups acquired different results. Generally, group 2 gave higher ratings for all statements ranging from 4.10 to 5.31 in comparison to group 1, with an average difference of 1.182.

# %% [markdown]
# ### Table 4. Two-sample t-tests for brand perception scores among groups
#
# | Statement | T-statistic | P-value |
# | :---: | :---: | :---: |
# | Apple is a premium brand | -2.43 | 0.02 |
# | Apple products are innovative | -4.37 | 6.17 x 10^-5 |
# | Apple products are well-desogned and aesthetically pleasing | -4.11 | 0.0001 |
# | Apple's brand reputation makes them a trustworthy brand | -4.49 | 4.22 x 10^-5 |
# | Owning Apple products affects how others perceive me | -3.95 | 0.0002 |
#
# Two-sample t-tests were conducted to test the significance of the difference in ratings among the two groups. All p-value results were below 0.05, indicating the two groups’ statistically different opinions.

# %% [markdown]
# ### Table 5. Top ten phrases used to describe Apple per group
#
# Group 1
#
# | Phrase | Frequency |
# | :---: | :---: |
# | Expensive | 9 |
# | Overpriced | 2 |
# | Aesthetic | 2 |
# | Sleek | 2 |
# | Ecosystem | 2 |
# | Simple | 2 |
# | Overrated | 2 |
# | Luxury | 2 |
# | Elegant | 1 |
# | Technological | 1 |
#
# Group 2
#
# | Phrase | Frequency |
# | :---: | :---: |
# | Innovative | 7 |
# | Expensive | 7 |
# | Simple | 6 |
# | Aesthetic | 6 |
# | Premium | 5 |
# | Minimalist | 3 |
# | Clean | 2 |
# | Minimalistic | 2 |
# | Exclusive | 2 |
# | Convenient | 2 |
#
# Table 5 shows the top words used as descriptors of Apple by the two groups. Group 1 extensively used the word “expensive”, with a difference of 7 with the next most common words, while group 2 used words like “innovative” and “simple”.

# %% [markdown]
# ### Table 6. Means of product ownership and purchase factor for technical devices scores for the overall sample
#
# | Statement | Mean |
# | :---: | :---: |
# | Number of Apple products owned | 1.98 |
# | Recommendations from friends and family back home | 2.98 |
# | Recommendations from friends at CUHK-Shenzhen | 2.23 |
# | Price and value for money | 3.62 |
# | Brand reputation and image | 2.96 |
# | Design, build quality, and aesthetics | 3.33 |
# | Technical specifications (e.g. RAM, memory, battery, camera) | 3.75 |
# | Operating system (e.g. iOS, Android) | 3.15 |
# | Integration with other devices (ecosystem) | 3.33 |
#
# *All factors (rows 2-9) are derived from 4-scale Likert questions
#
# Table 6 shows that technical specifications and price obtained the highest scores, followed by design, ecosystem, and operating system scoring moderately high, indicating their influences on purchase decisions.

# %% [markdown]
# ### Table 7. Means of product ownership and purchase factor for technical devices scores per group
#
# | Statement | Mean (Group 1) | Mean (Group 2) |
# | :---: | :---: | :---: |
# | Number of Apple products owned | 0.83 | 2.90 |
# | Recommendations from friends and family back home | 2.87 | 3.07 |
# | Recommendations from friends at CUHK-Shenzhen | 2.13 | 2.31 |
# | Price and value for money | 3.61 | 3.62 |
# | Brand reputation and image | 2.70 | 3.17 |
# | Design, build quality, and aesthetics | 3.04 | 3.55 |
# | Technical specifications (e.g. RAM, memory, battery, camera) | 3.70 | 3.79 |
# | Operating system (e.g. iOS, Android) | 2.70 | 3.51
# | Integration with other devices (ecosystem) | 3.00 | 3.55 |
#
# *All factors (rows 2-9) are derived from 4-scale Likert questions
#
# Data shows that group 2 owned more products than group 1. For the factors, technical specifications and price obtained a high score of around 3.6-3.7 for both groups. Additionally, group 2 rated design, ecosystem, and operating system moderately high, exceeding 3.5.

# %% [markdown]
# ### Table 8. Two-sample t-tests for brand perception scores among groups
#
# | Statement | T-statistic | P-value |
# | :---: | :---: | :---: |
# | Number of Apple products owned | -5.86 | 3.58 x 10^-7 |
# | Recommendations from friends and family back home | -0.98 | 0.33 |
# | Recommendations from friends at CUHK-Shenzhen | -0.80 | 0.43 |
# | Price and value for money | -0.08 | 0.94 |
# | Brand reputation and image | -2.10 | 0.04 |
# | Design, build quality, and aesthetics | -3.02 | 0.004 |
# | Technical specifications (e.g. RAM, memory, battery, camera) | -0.72 | 0.47 |
# | Operating system (e.g. iOS, Android) | -3.21 | 0.002 |
# | Integration with other devices (ecosystem) | -2.29 | 0.02 |
#
# T-tests were conducted to examine the significance of difference within the groups. Product ownership, brand reputation, product design, operating system, and ecosystem were proven to have a significant difference with p-values of below 0.05.

# %% [markdown]
# ### Figure 1. Overall barrier of purchase frequencies

# %%
Reason_Not_Own_Counts.plot(kind='barh', color=color[0])
# Out:
# <Axes: ylabel='Reason_Not_Buy'>

# %% [markdown]
# Figure 1 shows the reasons why students didn’t make any purchases from Apple. The main barrier price with 6 responses, followed by preference for competitors with half the number of responses.

# %% [markdown]
# ## Discussion
# The characteristics of the two groups can be identified from the results. Group 1 gave lower ratings with mixed and negative descriptors of the brand and only highly prioritize fundamental factors (price and technical specifications) when purchasing a technological product, making them less prone to symbolic branding. Contrastingly, group 2 gave higher ratings with positive reviews and focused on overall user experience by ecosystem, operating system, and design on top of the fundamental considerations. Additionally, group 1 owns less Apple products compared to group 2. This shows that the students’ views and key considerations of purchase directly impacts their decision.
#
# Group 1 holds a more skeptical position towards Apple products because their highest priority are only the fundamental factors, with lower levels of considerations for other factors, making them less likely to be swayed by marketing strategies that puts user experience and exclusivity as a driver of purchase, which is Apple’s current strategy. Moreover, this strategy seems to backfire for group 1, looking at their choices of words including “overrated” and “overpriced” to describe Apple. In contrast, group 2 is Apple’s targeted market. On top of the fundamental factors, they also consider product design, operating system, and ecosystem, which are secondary to functionality but enhances their experience while using the products, affecting their purchasing decisions. They also described Apple as “exclusive” and “premium”, indicating Apple’s success in their branding strategy for this market segment. Schlegelmilch (2022) confirmed that segmenting, targeting, and positioning are crucial elements in marketing strategies. Nagamia (2015) confirms the use of this strategy by Apple by mentioning that Apple targeting customers with higher levels of lifestyles.
#
# Results also show that regardless of grouping and ownership of Apple products, the respondents highly consider pricing. The two groups’ purchase decisions differ despite the similarities in this aspect. Group 1 perceived Apple as “overpriced”, showing a negative view towards Apple products’ pricing. Meanwhile, group 2 describing Apple as “exclusive” shows that Apple’s high pricing enhance their positive view of Apple. This is supported by findings showing that price sensitivity only has a moderate influence toward purchase intentions (Shang & Plaikaew, 2025). The same research indicated that some market segments perceive high prices as indicators of high quality, the difference in perceptions.

# %% [markdown]
# ## Conclusion
# As a conclusion, within the main market segment of international students at CUHK-Shenzhen, there were two sub-segments with noticeable differences in their views and behavior towards Apple. One group was more skeptical and emphasized only functionality and price, while the other was more enthusiastic and considered user experience. These beliefs shaped their purchasing decisions. Despite the differences, however, all respondents emphasize pricing in purchasing decisions.
#
# This research lacks depth in qualitative understanding of the respondents’ experience such as the reason why the Apple ecosystem eases daily usage of electronics as a student. Hence, further qualitative methods are encouraged for future research to gain knowledge about the respondents.
#
# This research implies that symbolic-based branding schemes alone are not sufficient for this specific market segment. Furthermore, companies should consider the dynamics and sub-segments in each target market, then adjust marketing strategies accordingly.

# %% [markdown]
# ## References
#
# Cai, Q., & Shen, S. (2024). Analysis of the influencing factors of marketing strategy on consumer purchasing behaviour: A case study of Apple. SHS Web of Conferences, 188, Article 03005. https://doi.org/10.1051/shsconf/202418803005
#
# Chen et al. (2021). Apple Inc. strategic marketing analysis and evaluation. Advances in Social Science, Education and Humanities Research, 203, 3053-3061. Atlantis Press. https://doi.org/10.2991/assehr.k.211209.499
#
# Douglas, H. N. (2025). Apple fetishization and student consumer culture: examining the influence of communication devices on undergraduate students' behaviour in Rivers State University. Journal for Media and Communication, 2(9), 1029-1039. Rapid Journals. https://rapidjournals.com/wp-content/uploads/journal/published_paper/volume-2/issue-9/rjip_dChedRaM.pdf
#
# Information Office of Shenzhen Municipal Government (2024). Shenzhen basics. Retrieved from Shenzhen Government Online: https://www.sz.gov.cn/en_szgov/aboutsz/profile/content/post_11666623.html
#
# Lan, B. (2021). Analysis of Apple's marketing strategy. Advances in Social Science, Education and Humanities Research, 543, 128-132. Atlantis Press. https://doi.org/10.2991/assehr.k.210407.026
#
# Li, Z. (2023). Strategic marketing – marketing analysis of Apple company. International Journal of Management Science Research, 6(4), 19-26. Adwen House of Publishing Limited. https://doi.org/10.53469/ijomsr.2023.6(04).04
#
# Nagamia, N. K. A. (2015). Apple Inc.: A marketing analysis case study. MacEwan University Student Ejournal, 2(1), 54-61. https://doi.org/10.31542/j.muse.216
# Schlegelmilch, B. B. (2022). Global Marketing Strategy. Switzerland: Springer Nature Switzerland AG.
#
# Shang, D., & Plaikaew, S. (2024). Impact of consumer preferences and brand perception on cell phone purchase intention: Moderating role of price sensitivity. Procedia of Multidisciplinary Research, 3(4). https://so09.tci-thaijo.org/index.php/PMR/article/view/6251
#
# Wang, J. (2024). CUHK-Shenzhen enrolls record number of new intl. students. Lin, Q. (Ed.). Eye Shenzhen. https://intladmissions.cuhk.edu.cn/en/article/332
# Wells, W. D., & Prensky, D. (1996). Consumer behavior. New York: John Wiley & Sons, Inc.
#
# World Bank. (2024). Population growth (annual %) – China. Retrieved from World Bank Group:  https://data.worldbank.org/indicator/SP.POP.GROW?locations=CN

# %% [markdown]
# ## Appendix
#
# Questionnaire questions
#
# A.	Demographics
#
# Home Country: _____
#
# Age: _____
#
# Gender: ____
#
# B.	Brand Perception
# 1.	For the following statements, please indicate your level of agreement. (1=Strongly Disagree, 2=Disagree, 3=Slightly Disagree, 4=Slightly Agree, 5=Agree, 6=Strongly Agree)
# - Apple is a premium brand
# - Apple products are innovative
# - Apple products are well-designed and aesthetically pleasing
# - Apple’s brand reputation makes them a trustworthy brand
# - Owning Apple products affects how others perceive me
# 2.	What words or phrases would you use to describe the brand Apple?
#
# C.	Purchasing Factors and Behaviors
#
# 1.	Which of the following Apple products do you currently own? (Select all that apply)
# - iPhone
# - MacBook
# - iPad
# - AirPods or AirPods Pro
# - Apple Watch
# - Apple Mouse
# - None of the above
# 2.	How important are the following factors when you consider purchasing a technological product (e.g. smartphone, laptop)? (1=Not at all important, 2=Slightly important, 3=Important, 4=Very important)
# - Recommendations from friends and family back home
# - Recommendations from friends at CUHK-Shenzhen
# - Price and value for money
# - Brand reputation and image
# - Design, build quality, and aesthetics
# - Technical specifications (e.g. RAM, memory, battery, camera)
# - Operating system (e.g. iOS vs. Android)
# - Integration with my other devices (ecosystem)
# 3.	If you have chosen not to purchase an Apple product, what was the main reason?
# - I prefer the features of other brands
# - Apple products are too expensive
# - I am not convinced of their quality
# - I have concerns about the compatibility in China
# - N/A – I do own Apple products
